# %% [markdown]
# # Seventh Exercise (Chapter 3 & Chapter 14)
#
# In the first part we will recap basics of probability theory.
#
# In the second part, we're going to implement an autoencoder and explore the learned latent space.

# %% [markdown]
# ## 7.1 Probability
#
# Solve the first two exercises mathematically. Answer using markdown and latex in this notebook. Please provide intermediate steps and explanations.
#
# ### 7.1.1 Bertrand's Box Paradox
#
# Consider a box containing the following 3 cards
#
# - one with two black sides
# - one with two white sides
# - one with a black and a white side
#
# From the three cards, one is drawn at random and put on the table. You can only see the side facing up.
#
# **Questions:**
#
# a) What are the probabilities that the card on the table shows a black side? What are the probabilities it shows a white side?
# b) If we draw a card and it shows black, compute the probability that the other side of the card is also black.
# c) Find the the probability that the other side of the card is black if the card shows a white side.

# %% [markdown]
# **Answers:**
#
# a) If you pick a card (out of 3 cards) and put it on the table, there are a total of 6 possible outcomes.
# Total outcomes = 6
# No.of occurence of the event (card is black) = 3
#
# $$P(C_1=black) = \frac{3}{6} = \frac{1}{2}$$
#
# Similarly,
# $$P(C_1=white = \frac{3}{6} = \frac{1}{2} $$
#
# b) If we pick a card out of 3 cards, the probability that both sides are black $$P(C_1=black,C_2=black) = 1/3$$
# So,
# $$P(C_1=black|C_2=black) = \frac{P(C_1=black,C_2=black)}{P(C_2=black)} = \frac{\frac{1}{3}}{\frac{1}{2}} = \frac{2}{3}\hspace{1cm} [P(C_2=black) = P(C_1=black)\hspace{0.1cm}from\hspace{0.1cm}(a)]$$
#
# c) If we pick a card out of 3 cards, the probability that both sides are different $$P(C_1=black,C_2=white) = 1/3$$
# So,
# $$P(C_1=black|C_2=white) = \frac{P(C_1=black,C_2=white)}{P(C_2=white)} = \frac{\frac{1}{3}}{\frac{1}{2}} = \frac{2}{3}\hspace{1cm} [P(C_2=white) = P(C_1=white)\hspace{0.1cm}from\hspace{0.1cm}(a)]$$

# %% [markdown]
# ## 7.1.2 Entropy and Kullback Leibler Divergence
#
# **Questions:**
#
# a) Compute the Entropy of the normal distribution
#
# \begin{equation*}
# \mathcal N(x; \mu,\sigma) = \frac{1}{\sqrt{2\pi\sigma^2}} \mathrm{e}^{-\frac{(x-\mu)^2}{2\sigma^2}}\,.
# \end{equation*}
#
# b) Find the Kullback-Leibler divergence between two Gaussian distributions, i.e.
#
# \begin{equation*}
# D_{KL}\left( \mathcal N(\mu_1, \sigma_1) \vert\vert \mathcal N(\mu_2, \sigma_2) \right)\,.
# \end{equation*}

# %% [markdown]
# **Answers:** **TODO**
#
# a) The Entropy of the normal distribution:
# \begin{equation*}
# \begin{aligned}
# p(x) &= \mathcal N(x; \mu,\sigma) = \frac{1}{\sqrt{2\pi\sigma^2}} \mathrm{e}^{-\frac{(x-\mu)^2}{2\sigma^2}}\,.\\
# H   &= \int_{-\infty}^\infty p(x)\hspace{0.1cm}[-log\hspace{0.1cm} p(x)]\hspace{0.1cm}dx\\&=  \int_{-\infty}^\infty p(x)\hspace{0.1cm}[\frac{1}{2}\hspace{0.1cm}log\hspace{0.1cm}(2\pi\sigma^2) + \frac{1}{2\sigma^2}(x-\mu)^2]\hspace{0.1cm}dx \hspace{1cm} [Substituting\hspace{0.3cm}p(x) = \frac{1}{\sqrt{2\pi\sigma^2}} \mathrm{e}^{-\frac{(x-\mu)^2}{2\sigma^2}} \hspace{0.1cm} in\hspace{0.1cm}log\hspace{0.1cm}p(x)] \\&= \frac{1}{2}log\hspace{0.1cm}(2\pi\sigma^2)\hspace{0.1cm}[\int_{-\infty}^\infty p(x)\hspace{0.1cm}dx + \frac{1}{2\sigma^2}\int_{-\infty}^{\infty}\hspace{0.1cm}(x-\mu)^2)\hspace{0.1cm}p(x)\hspace{0.1cm}dx] \\&= The\hspace{0.1cm}second\hspace{0.1cm}term: \int_{-\infty}^{\infty}\hspace{0.1cm}(x-\mu)^2)\hspace{0.1cm}p(x)\hspace{0.1cm}dx = \sigma^2 \\ \therefore\hspace{1cm}H &= \frac{1}{2}[\hspace{0.1cm}log\hspace{0.1cm}(2\pi\sigma^2) + 1]
# \end{aligned}
# \end{equation*}
#
# Hence, entropy of the Gaussian probability density function depends only on the variance.
#
# b) The Kullback-Leibler divergence between two Gaussian distributions:
# \begin{equation*}
# \begin{aligned}
# &= D_{KL}\left( \mathcal N(\mu_1, \sigma_1) \vert\vert \mathcal N(\mu_2, \sigma_2) \right)
# \hspace{0.2cm}\left[Lets,\hspace{0.2cm} p(x) \sim \mathcal N(\mu_1, \sigma_1) \hspace{0.2cm}and\hspace{0.2cm} q(x) \sim  \mathcal N(\mu_2, \sigma_2)\right]
# \\D_{KL} \left( p \vert\vert q \right) &= \int p(x)\hspace{0.1cm}log\left[\frac{\frac{1}{\sqrt{2\pi\sigma_1^2}}\mathrm{e}^{-\frac{(x-\mu_1)^2}{2\sigma_1^2}}}{\frac{1}{\sqrt{2\pi\sigma_2^2}}\mathrm{e}^{-\frac{(x-\mu_2)^2}{2\sigma_2^2}}}\right]\hspace{0.1cm}dx
# \\ &= \int p(x)\hspace{0.1cm}log\left( \frac{\sigma_2^2}{\sigma_1^2} \right)^\frac{1}{2}dx + \int p(x) \left( -\frac{(x-\mu_1)^2}{2\sigma_1^2} + \frac{(x-\mu_2)^2}{2\sigma_2^2}\right) dx
# \\ &= \frac{1}{2}log\left( \frac{\sigma_2^2}{\sigma_1^2}\right) + \frac{1}{2\sigma_1^2}\left[-\int (x-\mu_1)^2p(x)dx\right]+\frac{1}{2\sigma_2^2}\left[-\int (x-\mu_2)^2p(x)dx\right]
# \\&= \frac{1}{2}log\left( \frac{\sigma_2^2}{\sigma_1^2}\right) - \frac{\sigma_1^2}{2\sigma_1^2} + \frac{1}{2\sigma_2^2}\int(x-\mu_1+\mu_1-\mu_2)^2p(x)dx
# \\&= \frac{1}{2}log\left( \frac{\sigma_2^2}{\sigma_1^2}\right) - \frac{1}{2} + \frac{1}{2\sigma_2^2}\left[\int(x-\mu_1)^2p(x)dx+(\mu_1-\mu_2)^2\int p(x)dx+2(\mu_1-\mu_2)\int(x-\mu_1)p(x)dx\right]
# \\&= \frac{1}{2}log\left( \frac{\sigma_2^2}{\sigma_1^2}\right) - \frac{1}{2} + \frac{1}{2\sigma_2^2}\left[\sigma_1^2+(\mu_1-\mu_2)^2 \right]
# \\ \therefore D_{KL}\left( \mathcal N(\mu_1, \sigma_1) \vert\vert \mathcal N(\mu_2, \sigma_2) \right) &= \frac{1}{2}\left[log \left( \frac{\sigma_2^2}{\sigma_1^2} \right) - 1 + \frac{\sigma_1^2+(\mu_1-\mu_2)^2}{\sigma_2^2} \right]
# \end{aligned}
# \end{equation*}
#
# KL divergence of two guassians depend on the ration of variance and difference in their means.

# %% [markdown]
# ## 7.1.3 Distributions and CLT
#
# The central limit theorem states that for i.i.d. random samples $\{X_i\}$ from an (almost) arbitrary distribution with given mean $\mu$ and variance $\sigma^2$, the mean $\frac{1}{n}\sum_{i=1}^n X_i$ follows approximately a normal distribution. More precisely, it reads
#
# \begin{equation*}
# 	\frac{1}{n} \sum_{i=1}^n X_i \xrightarrow{n\to\infty} \mathcal N(\mu, \frac{\sigma^2}{n})\,.
# \end{equation*}
#
# **Questions:**
#
# - a) Draw $n=1,16,64, 1024$ samples from the distributions below for $1024$ times (each). Draw for each (n, distribution) pair a histogram over the sample mean. Include the corresponding normal distribution (pdf) in the plot.
#
#     - the exponential distribution $p(X) = \lambda \mathrm{e}^{-\lambda X}$
#     - the Gaussian/normal distribution
# - b) Assume, that you can only sample from uniform distributions. Implement functions to sample from an approximated standard normal distribution and an approximated normal distribution. Plot the distributions in comparison to the numpy implementation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# a)
## START TODO ########################
samples = [1,16,64,1024]

for n in samples:
    x = []
    for i in range(1024):
        s = np.random.exponential(1,size=(n,))
        mu = np.mean(s)
        x.append(mu)
    plt.figure()    
    plt.title("Exponential Distribution")
    plt.xlabel("Sampled Mean (X)")
    plt.ylabel("P(X)")
    n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)


for n in samples:
    x = []
    for i in range(1024):
        s = np.random.normal(0,1,size=(n,))
        mu = np.mean(s)
        x.append(mu)
    plt.figure()   
    plt.title("Gaussian Distribution")
    plt.xlabel("Sampled Mean (X)")
    plt.ylabel("P(X)")
    n, bins, patches = plt.hist(x, 50, normed=1, facecolor='red', alpha=0.75)
    
## END TODO ########################
# Out:
# C:\Users\Neil\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# b)
def std_normal(n_samples: int = 1) -> np.ndarray:
    """ Sample from a standard normal distribution. 
        The normal distribution is approximated via a uniform dist.
    
        n_samples: number of samples of a standard normal distribution
        return:    samples. length = n_samples
    """
    ## START TODO ########################
    
    x = []
    for i in range(n_samples):
        s = 0.5*np.sum(np.random.uniform(-1,1,size=(12,)))
        #mu = np.mean(s)
        x.append(s)
    
    ## END TODO ########################
    return x

def normal(loc: float = 0.0, scale: float = 1.0, n_samples: int = 1) -> np.ndarray:
    """ Sample from a normal distribution.
        The normal distribution is approximated via a uniform dist.
    
        loc: mean of the distribution
        scale: standard deviation spread of the distribution.
        
        n_samples: number of samples
        return:    samples. length = n_samples
    """
    ## START TODO ########################
    x = []
    for i in range(n_samples):
        s = 0.5*np.sum(np.random.uniform(-scale,scale,size=(12,))) + loc
        #mu = np.mean(s)
        x.append(s)
    ## END TODO ########################

    return x
n_samples = 10000
bins = 20

# plot histograms for standard normal with std_normal and np.random.normal
## START TODO ########################
x = std_normal(n_samples)
plt.figure()   
plt.title("Gaussian Distribution with std_normal")
plt.xlabel("(X)")
plt.ylabel("P(X)")
n, bins, patches = plt.hist(x, bins, facecolor='red', alpha=0.75)

x = np.random.normal(0,1,n_samples)
plt.figure()   
plt.title("Gaussian Distribution with np.random.normal")
plt.xlabel("(X)")
plt.ylabel("P(X)")
n, bins, patches = plt.hist(x, bins, facecolor='green', alpha=0.75)

## END TODO ########################

# plot histograms for N(mean=-10, std=3) with normal and np.random.normal
## START TODO ########################
x = normal(-10,3,n_samples)
plt.figure()   
plt.title("Gaussian Distribution with std_normal")
plt.xlabel("(X)")
plt.ylabel("P(X)")
n, bins, patches = plt.hist(x, bins, facecolor='blue', alpha=0.75)

x = np.random.normal(-10,3,n_samples)
plt.figure()   
plt.title("Gaussian Distribution with np.random.normal")
plt.xlabel("(X)")
plt.ylabel("P(X)")
n, bins, patches = plt.hist(x, bins, facecolor='yellow', alpha=0.75)

## END TODO ########################

# %% [markdown]
# ### Your Feedback on Exercise 7.1
#
# * **Major Problems:** It took a lot of time to write all the equations and symbols in markdown latex.
# * **Helpful?** Yes. It gave a good intuition about KL divergence and central limit theorem.
# * **Duration (hours):** 5 hrs
# * **Other feedback:** To sum up, this exercise was a quick revision of the basic probability concepts, entropy and KL divergence.

# %% [markdown]
# ## 7.2 Autoencoder
#
# Let's now implement our own variational auto encoder (VAE). The VAE is described in chapter 20.10.3 of the Deep Learning Book and you can find the original paper [here](https://arxiv.org/pdf/1312.6114.pdf).
#
# Compared to a "standard" auto encoder, a VAE learns to approximate the posterior.

# %%
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision
# Out:
# 0.3.0.post4

# %%
from __future__ import print_function
import os
import argparse
from typing import Tuple

import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image

import numpy as np
import matplotlib.pyplot as plt

# %%
torch.manual_seed(0)
device = torch.device("cpu")

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
    transform=transforms.Compose([transforms.ToTensor()])),
    batch_size=128, shuffle=True)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.ToTensor()),
    batch_size=128, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
class VAE(nn.Module):
    def __init__(self, latent_space_size=2):
        super(VAE, self).__init__()
      
        """Variational auto encoder.
        
        Create the VAE with the MLP encoder having one hidden layer
        and two output layers (mean and log of the variance).
        Use a hidden size of 100 and each output size of `latent_space_size`.
        
        The decoder should be as powerful as the encoder.
        """
        input_size = 784
        hidden_size = 100
        ## START TODO ########################
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        self.z_mu = nn.Linear(hidden_size, latent_space_size)  
        self.z_var = nn.Linear(hidden_size, latent_space_size)
        self.fc2 = nn.Linear(latent_space_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, input_size)
        
        
        ## END TODO ########################


    def encode(self, x) -> Tuple[torch.Tensor, torch.Tensor]:
        """ Encode x to distribution.
        
        Compute the hidden representation. Estimate and return the mean
        and the log of the variance from the hidden representation. Use
        relu as activation function for the hidden representation.
        """
        ## START TODO ########################
        out = self.fc1(x)
        out = self.relu(out)
        z_mu = self.z_mu(out)
        z_var = self.z_var(out)
        return z_mu, z_var

        #raise NotImplementedError
        ## END TODO ########################
    
    def reparameterize(self, mu, logvar) -> torch.Tensor:
        """Sample from the estimated distribution.
        
        In training mode, return a sample from N(mu, logvar).
        In evaluation mode, just return the mean.
        
        Hint: You estimate the log of the variance, so you need to transform
        this to std deviation first, as torch.randn
        """
        ## START TODO ########################
        
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)
        #raise NotImplementedError
        ## End TODO ########################

    def decode(self, z) -> torch.Tensor:
        """ Decode the latent representation.
        
        Compute the hidden representation from the latent space z,
        use relu as activation. Then reconstruct the signal from
        the hidden representation, using a sigmoid as activation.
        """
        ## START TODO ########################
        out = self.fc2(z)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.sigmoid(out)
        return out
        
        #raise NotImplementedError
        ## END TODO ########################

    def forward(self, x) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """Encode, reparameterize and decode.
        
        Returns:
            (The decoded result, mu, logvar)
        """
        ## START TODO ########################
        z_mu,z_var = self.encode(x.view(-1,784))
        z = self.reparameterize(z_mu,z_var)
        res = self.decode(z)
        
        return (res,z_mu,z_var)
        #raise NotImplementedError
        ## END TODO ########################

# %%
# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(x_reconstructed, x, mu, logvar, kl_loss_weight=1):
    ## START TODO ########################
    # compute the binary cross entropy between x and the reconstructed x
    
    rec_loss = F.binary_cross_entropy(x_reconstructed, x.view(-1,784), reduction='sum')
    
    
    # Here your results from 7.1.2 come into play - The first distribution is
    # the N(mu, logvar) and the second is N(0, 1). Plugging this into
    # the result from 7.1.2 yields
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    # you can also check Appendix B from the VAE paper:
    # https://arxiv.org/abs/1312.6114
    
    kl_div_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    ## END TODO ########################
    return rec_loss + kl_div_loss * kl_loss_weight

# %%
def train(model, epoch, optimizer, kl_loss_weight=1, save_images=False):
    model.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        reconstructed_batch, mu, logvar = model(data)
        loss = loss_function(reconstructed_batch, data, mu, logvar, kl_loss_weight)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
    if save_images:
        n = min(data.size(0), 8)
        training_image = torch.cat([data[:n]])
        save_image(training_image.cpu(),
                   'results/training_samples_' + str(epoch) + '.png', nrow=n)

    print('====> Epoch: {} Average train set loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader.dataset)))


def test(model, epoch, kl_loss_weight=1, save_images=False):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for i, (data, _) in enumerate(test_loader):
            data = data.to(device)
            reconstructed_batch, mu, logvar = model(data)
            test_loss += loss_function(reconstructed_batch, data, mu, logvar, kl_loss_weight).item()
            if i == 0:
                n = min(data.size(0), 8)
                comparison = torch.cat([data[:n],
                                      reconstructed_batch.view(128, 1, 28, 28)[:n]])
                if not save_images:
                    continue
                save_image(comparison.cpu(),
                         'results/reconstruction_' + str(epoch) + '.png', nrow=n)

    test_loss /= len(test_loader.dataset)
    print('====> Average test set loss: {:.4f}'.format(test_loss))

# %%
latent_space_size = 2
model = VAE(latent_space_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

if not os.path.isdir('results'):
    os.mkdir('results')

for epoch in range(1, 15):
    train(model, epoch, optimizer, save_images=True)
    test(model, epoch, save_images=True)
    with torch.no_grad():
        ## START TODO ########################
        # sample 64 images (generate a random latent_space and decode)
        sample = torch.randn(64, 2).to(device)
        sample = model.decode(sample).cpu()
        ## END TODO ########################
        save_image(sample.view(64, 1, 28, 28),
                   'results/sample_' + str(epoch) + '.png')
# Out:
# ====> Epoch: 1 Average train set loss: 210.7327
# ====> Average test set loss: 181.5973
# ====> Epoch: 2 Average train set loss: 177.6184
# ====> Average test set loss: 172.8943
# ====> Epoch: 3 Average train set loss: 171.0516
# ====> Average test set loss: 168.1809
# ====> Epoch: 4 Average train set loss: 167.6239
# ====> Average test set loss: 165.7625
# ====> Epoch: 5 Average train set loss: 165.3859
# ====> Average test set loss: 163.7394
# ====> Epoch: 6 Average train set loss: 163.8102
# ====> Average test set loss: 162.5339
# ====> Epoch: 7 Average train set loss: 162.6103
# ====> Average test set loss: 161.7355
# ====> Epoch: 8 Average train set loss: 161.5945
# ====> Average test set loss: 160.9056
# ====> Epoch: 9 Average train set loss: 160.8207
# ====> Average test set loss: 160.1868
# ====> Epoch: 10 Average train set loss: 160.1864
# ====> Average test set loss: 159.7769
# ====> Epoch: 11 Average train set loss: 159.6344
# ====> Average test set loss: 159.2503
# ====> Epoch: 12 Average train set loss: 159.1131
# ====> Average test set loss: 158.6958
# ====> Epoch: 13 Average train set loss: 158.6674
# ====> Average test set loss: 158.2835
# ====> Epoch: 14 Average train set loss: 158.2816
# ====> Average test set loss: 158.0107

# %% [markdown]
# ## Exploring the latent space
#
# One of the easiest ways to visualize the latent space is to limit the size to two dimensions (which of course might not always capture the data well) and to sample from the model over a 2D grid. This is what we're going to do below. Also, we can nicely visualize the concept of a VAE. We plot the mean over the estimated means for each class (the numbers 0 to 9) and the mean estimated standard deviation for each class (the blue crosses).

# %%
def get_mu_logvar(model: nn.Module) -> Tuple[torch.Tensor, torch.Tensor]:
    """Compute the model's prediction of mean and logvar for all
       images in the MNIST test set.
    """
    mus, logvars = [], []
    # encode each image of the test_loader
    ## START TODO ########################
    model.eval()
    for i, (data, _) in enumerate(test_loader):
        data = data.to(device)
        reconstructed_batch, mu, logvar = model(data)
        mus.append(mu)
        logvars.append(logvar)
    ## END TODO ########################
    return torch.cat(mus), torch.cat(logvars)

    
def sample_on_grid(latent_min: Tuple[int, int], latent_max: Tuple[int, int], 
                   model: nn.Module, grid_size: int) -> Tuple[np.ndarray, np.ndarray]:
    ## START TODO ########################
    # create a grid in two directions from latent_min to latent_max, using
    # the respective dimension
    x1 = np.random.uniform(latent_min[0],latent_max[0],size=(grid_size * grid_size,1))
    x2 = np.random.uniform(latent_min[1],latent_max[1],size=(grid_size * grid_size,1))
    # use the created grid as latent variables and run them through the decoder
    z = np.column_stack((x1,x2))
    print(z.shape)
    decoded = model.decode(torch.from_numpy(z).float()).cpu()
    ## END TODO ########################
    step_size = np.array((x1[1] - x1[0], x2[1] - x2[0]))
    return decoded.detach().numpy().reshape(grid_size, grid_size, 28, 28), step_size


def plot_latent_space(model: nn.Module):
    model.eval()
    mus, logvars = get_mu_logvar(model)
    mus = mus.detach().numpy()
    stddev = np.exp(0.5*logvars.detach().numpy())

    labels = torch.cat([label for _, label in test_loader]).detach().numpy()
    num_samples = labels.shape[0]
    class_mu_0 = np.bincount(labels, weights=mus[:, 0]) / np.bincount(labels)
    class_mu_1 = np.bincount(labels, weights=mus[:, 1]) / np.bincount(labels)
    mean_mu = np.stack((class_mu_0, class_mu_1))
    print("Per class mean of estimated mean:\n", mean_mu)

    class_stddev_0 = np.bincount(labels, weights=stddev[:, 0]) / np.bincount(labels)
    class_stddev_1 = np.bincount(labels, weights=stddev[:, 1]) / np.bincount(labels)
    mean_stddev = np.stack((class_stddev_0, class_stddev_1))
    print("Per class mean of estimated std deviation:\n", mean_stddev)

    # get the minimum and maximum values of the latent space means
    # we will use this as boundaries from which we sample in the latent space
    latent_min = np.min(mean_mu - mean_stddev * 2, axis=1)
    latent_max = np.max(mean_mu + mean_stddev * 2, axis=1)

    # Produce a 20x20 2D grid of evenly spaced values between latent_min ant latent_max
    decoded, step_size = sample_on_grid(latent_min, latent_max, model, grid_size=20)
    
    # visualize the decoded images
    # using reshape and np.concatenate and calling imshow only once
    # is a lot faster than creating a subplot and calling imshow 400 times.
    # It's also necessary to be able to plot the means
    block_img = np.concatenate(np.concatenate(decoded, axis=1), axis=1)
    f = plt.figure(figsize=(12,12))
    plt.imshow(block_img, cmap='Greys')
    plt.axis('off');

    # visualize the mean mu and the mean standard deviation of each class
    # scale the mean accordingly, as the plot's axes represent pixels
    scale = (28 / step_size)

    mean_mu_scaled = 28/2 + scale.reshape(2, 1) * (mean_mu - latent_min.reshape(2,1))
    # we scale the stddev by 2 so the arrows are extended a bit more
    mean_stddev_scaled = mean_stddev * scale.reshape(2, 1) * 2
    # plot the std deviation
    plt.errorbar(mean_mu_scaled[0], mean_mu_scaled[1],
                 yerr=mean_stddev_scaled[1], xerr=mean_stddev_scaled[0],
                 linestyle='None')
    # plot the means
    plt.scatter(mean_mu_scaled[0], mean_mu_scaled[1])

    for i, txt in enumerate([str(i) for i in range(0,10)]):
        plt.annotate(txt, (mean_mu_scaled[0][i] + 3, mean_mu_scaled[1][i] - 3),
                     color='blue',
                     bbox={'facecolor':'white', 'alpha':0.9, 'pad':1, 'edgecolor':'none'})
    plt.show()

plot_latent_space(model)
# Out:
# Per class mean of estimated mean:
#  [[-2.06804312  2.62493592  0.42485063  0.61075877  0.09795667  0.19148857
#   -0.66822671  0.97311383  0.63857694  0.34952749]
#  [-0.20762287 -0.98810917 -0.63559996 -0.11597528  1.41733288 -0.35761651
#   -0.32092745  2.41258064  0.02963884  1.69685645]]
# Per class mean of estimated std deviation:
#  [[0.14298221 0.22346807 0.08217791 0.09445052 0.09308573 0.10237304
#   0.09452527 0.11489171 0.10059745 0.09921374]
#  [0.09098823 0.13466042 0.06831607 0.07343848 0.12026717 0.10240815
#   0.08120315 0.16211358 0.09647024 0.13146085]]
# (400, 2)

# %% [markdown]
# ## Exploring the influence of the KL-divergence in the loss
#
# Let's now investigate the influence of the KL-divergence by training
# - one model where we weight the KL-divergence part of the loss by a factor of 30 and
# - one model where we remove it (weight 0).
#
# Visualize the latent space as we did above.
#
# **ToDo** What do you observe? How can these results be explained? What is the role of the KL divergence term?

# %%
## START TODO ########################
latent_space_size = 2
model_large_kl = VAE(latent_space_size).to(device)
optimizer = optim.Adam(model_large_kl.parameters(), lr=1e-3)

for epoch in range(1, 15):
    train(model_large_kl, epoch, optimizer,kl_loss_weight=30, save_images=False)
    test(model_large_kl, epoch, save_images=False)
    sample=torch.rand(64,latent_space_size).to(device)
    sample=model_large_kl.decode(sample).cpu()
    save_image(sample.view(64, 1, 28, 28),
                   'results/sample_largeKL_' + str(epoch) + '.png')


    
 ## END TODO ########################
# Out:
# ====> Epoch: 1 Average train set loss: 237.7702
# ====> Average test set loss: 206.9447
# ====> Epoch: 2 Average train set loss: 207.0886
# ====> Average test set loss: 205.9303
# ====> Epoch: 3 Average train set loss: 206.5430
# ====> Average test set loss: 205.6830
# ====> Epoch: 4 Average train set loss: 206.3689
# ====> Average test set loss: 205.8586
# ====> Epoch: 5 Average train set loss: 206.3191
# ====> Average test set loss: 205.9558
# ====> Epoch: 6 Average train set loss: 206.2926
# ====> Average test set loss: 205.7943
# ====> Epoch: 7 Average train set loss: 206.2606
# ====> Average test set loss: 205.8249
# ====> Epoch: 8 Average train set loss: 206.2217
# ====> Average test set loss: 205.7212
# ====> Epoch: 9 Average train set loss: 206.2503
# ====> Average test set loss: 205.7595
# ====> Epoch: 10 Average train set loss: 206.2161
# ====> Average test set loss: 205.7556
# ====> Epoch: 11 Average train set loss: 206.1991
# ====> Average test set loss: 205.5836
# ====> Epoch: 12 Average train set loss: 206.1840
# ====> Average test set loss: 205.5815
# ====> Epoch: 13 Average train set loss: 206.1857
# ====> Average test set loss: 205.1156
# ====> Epoch: 14 Average train set loss: 206.1577
# ====> Average test set loss: 204.7114

# %%
plot_latent_space(model_large_kl)
# Out:
# Per class mean of estimated mean:
#  [[ 3.61096749e-02 -1.54185815e-02  8.00778136e-03  5.12779510e-03
#   -8.90043262e-03  4.70687821e-03  4.81189480e-03 -1.48383551e-02
#    3.17412386e-04 -1.30022611e-02]
#  [-5.08597102e-01  2.89110874e-01 -1.01578559e-01 -3.54829953e-02
#    5.09755067e-02 -4.16541287e-02 -1.03547026e-01  1.57451467e-01
#    1.80129322e-02  1.23483898e-01]]
# Per class mean of estimated std deviation:
#  [[0.9701171  1.0197939  0.98350388 0.99134197 0.99494865 0.99691492
#   0.98392787 1.00340375 0.99316451 0.9991561 ]
#  [0.97741774 0.97719817 0.95871762 0.96550361 0.95868796 0.97353399
#   0.95668923 0.96352699 0.9623561  0.95928511]]
# (400, 2)

# %%
## START TODO ########################
model_no_kl = VAE(latent_space_size).to(device)
optimizer = optim.Adam(model_no_kl.parameters(), lr=1e-3)

for epoch in range(1, 15):
    train(model_no_kl, epoch, optimizer,kl_loss_weight=0, save_images=False)
    test(model_no_kl, epoch, save_images=False)
    sample=torch.rand(64,latent_space_size).to(device)
    sample=model_large_kl.decode(sample).cpu()
    save_image(sample.view(64, 1, 28, 28),
                   'results/sample_noKL_' + str(epoch) + '.png')


    
## END TODO ########################
# Out:
# ====> Epoch: 1 Average train set loss: 200.5246
# ====> Average test set loss: 267.5603
# ====> Epoch: 2 Average train set loss: 171.5613
# ====> Average test set loss: 259.7528
# ====> Epoch: 3 Average train set loss: 165.8677
# ====> Average test set loss: 255.4787
# ====> Epoch: 4 Average train set loss: 161.8637
# ====> Average test set loss: 252.2355
# ====> Epoch: 5 Average train set loss: 159.2817
# ====> Average test set loss: 251.3657
# ====> Epoch: 6 Average train set loss: 157.4964
# ====> Average test set loss: 255.9850
# ====> Epoch: 7 Average train set loss: 156.1685
# ====> Average test set loss: 258.8036
# ====> Epoch: 8 Average train set loss: 155.0190
# ====> Average test set loss: 266.2931
# ====> Epoch: 9 Average train set loss: 154.0852
# ====> Average test set loss: 272.9551
# ====> Epoch: 10 Average train set loss: 153.3024
# ====> Average test set loss: 272.3750
# ====> Epoch: 11 Average train set loss: 152.6370
# ====> Average test set loss: 275.5114
# ====> Epoch: 12 Average train set loss: 152.0688
# ====> Average test set loss: 280.9258
# ====> Epoch: 13 Average train set loss: 151.5452
# ====> Average test set loss: 283.5622
# ====> Epoch: 14 Average train set loss: 151.0813
# ====> Average test set loss: 289.5673

# %%
plot_latent_space(model_no_kl)
# Out:
# Per class mean of estimated mean:
#  [[  3.19329415 -21.79727616  -1.6649754   -8.59095353  -7.74460531
#    -5.60556489  -0.43952307 -17.30050238  -5.21629015 -12.61716284]
#  [ 10.00577258 -12.89482874   4.25785308  12.93914072   3.43332319
#     6.81260261  10.56911292   4.91717206   2.78912647   4.69843427]]
# Per class mean of estimated std deviation:
#  [[0.0008018  0.00307371 0.00377597 0.00165303 0.00153424 0.00226486
#   0.00264108 0.00375828 0.00084806 0.00127476]
#  [0.00088208 0.00250991 0.00327276 0.00092869 0.0008197  0.00170215
#   0.00267083 0.00147824 0.00051131 0.00054298]]
# (400, 2)

# %% [markdown]
# ### Your Feedback on Exercise 7.2
#
# * **Major Problems:** sample_on_grid took max amount of time
# * **Helpful?** Visualization of latent space helped to understand what the network learns and what actually a latent space is
# * **Duration (hours):** 10h
# * **Other feedback:**
